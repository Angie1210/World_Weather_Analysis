# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
g_key="AIzaSyC3hjgaSWs502HKG-tnzBaJU81TPMhMB7c"

# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("../weather_challenge_database/WeatherPy_database.csv")
city_data_df.head()
# Out:
#    City_ID          City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0  Longyearbyen      SJ  78.2186   15.6401      1.24        60
# 1        1        Llanes      ES  43.4198   -4.7549     48.18        59
# 2        2       Samarai      PG -10.6167  150.6667     78.69        83
# 3        3   Yellowknife      CA  62.4560 -114.3525      0.28        61
# 4        4    Butaritari      KI   3.0707  172.7902     81.39        75
#
#    Cloudiness  Wind Speed Current Description
# 0          20        9.22          few clouds
# 1          41        7.83    scattered clouds
# 2          99        7.92       moderate rain
# 3          75        4.61       broken clouds
# 4          42       14.90    scattered clouds

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 30
# What is the maximum temperature you would like for your trip? 75

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
city_data_df=city_data_df.loc[(city_data_df['Max Temp']>=min_temp)&\
                                (city_data_df['Max Temp']<max_temp)]

city_data_df
# Out:
#      City_ID        City Country      Lat       Lng  Max Temp  Humidity  \
# 1          1      Llanes      ES  43.4198   -4.7549     48.18        59
# 6          6     Rikitea      PF -23.1203 -134.9692     74.17        57
# 8          8   Busselton      AU -33.6500  115.3333     71.85        73
# 11        11     Mataura      NZ -46.1927  168.8643     46.13        98
# 13        13      Albany      US  42.6001  -73.9662     47.57        41
# ..       ...         ...     ...      ...       ...       ...       ...
# 694      694      Jiaohe      CN  43.7286  127.3447     34.11        56
# 695      695  Miles City      US  46.4083 -105.8406     49.17        40
# 704      704  Huntsville      US  34.7304  -86.5861     58.78        56
# 705      705   Bonavista      CA  48.6499  -53.1147     37.31        92
# 706      706   Tongchuan      CN  35.0806  109.0897     46.87        35
#
#      Cloudiness  Wind Speed Current Description
# 1            41        7.83    scattered clouds
# 6            48        8.19    scattered clouds
# 8            98        5.50     overcast clouds
# 11           68        2.35       broken clouds
# 13            4        5.99           clear sky
# ..          ...         ...                 ...
# 694          18        4.32          few clouds
# 695           0        8.05           clear sky
# 704         100        8.01     overcast clouds
# 705          97       19.91     overcast clouds
# 706           0        3.94           clear sky
#
# [377 rows x 10 columns]

# %%
# 4a. Determine if there are any empty rows.
city_data_df.count()
# Out:
# City_ID                377
# City                   377
# Country                374
# Lat                    377
# Lng                    377
# Max Temp               377
# Humidity               377
# Cloudiness             377
# Wind Speed             377
# Current Description    377
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
city_data_df=city_data_df.dropna()

city_data_df
# Out:
#      City_ID        City Country      Lat       Lng  Max Temp  Humidity  \
# 1          1      Llanes      ES  43.4198   -4.7549     48.18        59
# 6          6     Rikitea      PF -23.1203 -134.9692     74.17        57
# 8          8   Busselton      AU -33.6500  115.3333     71.85        73
# 11        11     Mataura      NZ -46.1927  168.8643     46.13        98
# 13        13      Albany      US  42.6001  -73.9662     47.57        41
# ..       ...         ...     ...      ...       ...       ...       ...
# 694      694      Jiaohe      CN  43.7286  127.3447     34.11        56
# 695      695  Miles City      US  46.4083 -105.8406     49.17        40
# 704      704  Huntsville      US  34.7304  -86.5861     58.78        56
# 705      705   Bonavista      CA  48.6499  -53.1147     37.31        92
# 706      706   Tongchuan      CN  35.0806  109.0897     46.87        35
#
#      Cloudiness  Wind Speed Current Description
# 1            41        7.83    scattered clouds
# 6            48        8.19    scattered clouds
# 8            98        5.50     overcast clouds
# 11           68        2.35       broken clouds
# 13            4        5.99           clear sky
# ..          ...         ...                 ...
# 694          18        4.32          few clouds
# 695           0        8.05           clear sky
# 704         100        8.01     overcast clouds
# 705          97       19.91     overcast clouds
# 706           0        3.94           clear sky
#
# [374 rows x 10 columns]

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.


hotel_df=city_data_df[['City','Country','Max Temp',"Current Description",'Lat', 'Lng']].copy()



# 5b. Create a new column "Hotel Name"


hotel_df["Hotel Name"]=""
hotel_df
# Out:
#            City Country  Max Temp Current Description      Lat       Lng  \
# 1        Llanes      ES     48.18    scattered clouds  43.4198   -4.7549
# 6       Rikitea      PF     74.17    scattered clouds -23.1203 -134.9692
# 8     Busselton      AU     71.85     overcast clouds -33.6500  115.3333
# 11      Mataura      NZ     46.13       broken clouds -46.1927  168.8643
# 13       Albany      US     47.57           clear sky  42.6001  -73.9662
# ..          ...     ...       ...                 ...      ...       ...
# 694      Jiaohe      CN     34.11          few clouds  43.7286  127.3447
# 695  Miles City      US     49.17           clear sky  46.4083 -105.8406
# 704  Huntsville      US     58.78     overcast clouds  34.7304  -86.5861
# 705   Bonavista      CA     37.31     overcast clouds  48.6499  -53.1147
# 706   Tongchuan      CN     46.87           clear sky  35.0806  109.0897
#
#     Hotel Name
# 1
# 6
# 8
# 11
# 13
# ..         ...
# 694
# 695
# 704
# 705
# 706
#
# [374 rows x 7 columns]

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# 6b. Iterate through the hotel DataFrame.

for index, row in hotel_df.iterrows():
     
    
    # 6c. Get latitude and longitude from DataFrame 
    lat = row["Lat"]
    lng = row["Lng"]

   
    params["location"] = f"{lat},{lng}"

    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    
    # 6e. Make request and retrieve the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()
    
    # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the c
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
        print(hotels["results"][0]["name"])
    except (IndexError):
        print("Hotel not found... skipping.")
# Out:
# Hotel La Paz
# People ThankYou
# Observatory Guest House
# Ellie's Villa
# Hotel not found... skipping.
# ibis budget Newport
# Super 8 by Wyndham Fortuna
# Gulisitan Hotel
# Sheraton Kauai Coconut Beach Resort
# Sharm Hotel
# Hotel do Campo
# Radisson Blu Hotel Waterfront, Cape Town
# departamento comodo
# The Esplanade Resort & Spa
# Paradise Inn
# Timotel Hotel
# Holiday Inn Express & Suites Superior - Duluth Area, an IHG Hotel
# Hotel Hain
# The Halyards Hotel
# Misty Waves Boutique Hotel
# Hotel Porto Santo & Spa
# Albatross Hotel
# Hostal Las Lilas
# Tu Casa
# Snow's Cove Lodge
# Bredasdorp Country Manor
# The Shingles Riverside Cottages
# Brīvdienu Māja Trīs istabas
# Hotel not found... skipping.
# Hotel not found... skipping.
# Gallows Cove
# Holiday Inn Express Antofagasta, an IHG Hotel
# guarderia imss papalote
# Crowne Plaza Ordos
# Fortuna
# Zelenaya Pristan'
# St Ives Hobart Accommodation Tasmania
# B&B La Casona de Nazaret
# Hotel Santa Cruz
# Shanti Maurice Resort & Spa
# Hampton Inn & Suites Show Low-Pinetop
# Ayi The Costel
# Rayen-Co, Rural Tourism
# Mini Hotel Central
# Port Lincoln Hotel
# 安顺麦吉风格酒店
# Hotel Chik Chik Namibe
# Manyue Condo Hotel
# Courtyard by Marriott Danbury
# Nanning Travelling With Hostel
# Oyster Bay House Rental
# Hotell Marena
# Hôtel M'Sallah
# Sangthong Resort
# Gran Hotel Mar del Plata
# Taloa Heights
# Wanaka Homestead Lodge and Cottages
# Pistut
# Desert Gardens Hotel - Ayers Rock Resort
# Bjarnabúð
# Thanda Vista B&B
# Apartment above Depot Bar
# Courtyard by Marriott Pittsburgh Greensburg
# Kaitangata Motor Camp
# Базилик Щигры
# Blue Bay Lodge
# املاك خالد الشعشوع
# Hotel not found... skipping.
# Das Hotel an der Stadthalle
# Hotel Kawissa Saurimo
# Ekohospresurs
# Hotel Arctic
# Coast Retreat Muriwai - Golf and Surf Holiday
# Lovers Point Inn
# სასტუმრო ამირანი
# Inubosaki Kanko Hotel
# Hilton Garden Inn Qidong
# 帕米尔青年旅舍
# Herdeiros de Antunes Capusso
# Methoni Beach Hotel
# Hotel Sisimiut
# Hotel JM Puerto del Rosario
# Gostevoy Dom 1
# Hotel not found... skipping.
# Vila Nova Hotel
# Аренда жилья/Баня
# Hotel Meligai Kapit
# North Gate Hostel
# Alaska's Select Inn Wasilla
# عمارت ساعتی تفت
# Hótel Höfn
# Pereybere Hotel & Spa
# Hotel Nemuro Kaiyoutei
# Hotel not found... skipping.
# マースガーデンウッド御殿場
# Holiday Inn Express & Suites Kansas City-Grandview
# Meadow Brook Mobile Estates
# Hotel Beatriz
# Knobby's Fly-In Camps
# Siang Guest House
# Majestic Oasis Apartments
# Harmony Inn
# Hotel not found... skipping.
# Best Western Smoky Mountain Inn
# Maqna Hotel by Prasanthi
# Jinjiang Inn Zhoushan Putuo Shenjiamen
# عمارة السفير
# Aletti Palace Hotel
# Durrant House Hotel
# Shimoda Tokyu Hotel
# Hotel not found... skipping.
# Royal Hotel
# HOTEL TERME DI RAPOLLA
# บ้านห้องนอน
# Hotel not found... skipping.
# Adair Arms Hotel
# Ahipara Holiday Park
# Days Inn & Suites by Wyndham Warman Legends Centre
# Petawawa River Inn & Suites
# Hotel SJ
# Capo Peloro Resort
# Comfort Inn & Suites
# いこいの村なみえ
# U Ally Hotel
# Hotel Boutique Runde
# First Hotel Stadt
# Mercure Livingston Hotel
# Tora Coastal Walk
# MS Fuente Las Piedras
# Hôtel Barrière Le Royal La Baule
# Lavochka
# Lindos Princess Beach Hotel
# Hotel Wictoria
# Bahcesaray Koyu Muhtarligi
# Home Inn Fashion Hotel
# FairBridge Inn & Suites Miles City
# Embassy Suites by Hilton Huntsville Hotel & Spa
# Sweet Sharons bnb
# Tongchuan Hotel

# %%
hotel_df
# Out:
#            City Country  Max Temp Current Description      Lat       Lng  \
# 1        Llanes      ES     48.18    scattered clouds  43.4198   -4.7549
# 6       Rikitea      PF     74.17    scattered clouds -23.1203 -134.9692
# 8     Busselton      AU     71.85     overcast clouds -33.6500  115.3333
# 11      Mataura      NZ     46.13       broken clouds -46.1927  168.8643
# 13       Albany      US     47.57           clear sky  42.6001  -73.9662
# ..          ...     ...       ...                 ...      ...       ...
# 694      Jiaohe      CN     34.11          few clouds  43.7286  127.3447
# 695  Miles City      US     49.17           clear sky  46.4083 -105.8406
# 704  Huntsville      US     58.78     overcast clouds  34.7304  -86.5861
# 705   Bonavista      CA     37.31     overcast clouds  48.6499  -53.1147
# 706   Tongchuan      CN     46.87           clear sky  35.0806  109.0897
#
#                                           Hotel Name
# 1                                       Hotel La Paz
# 6                                    People ThankYou
# 8                            Observatory Guest House
# 11                                     Ellie's Villa
# 13
# ..                                               ...
# 694                           Home Inn Fashion Hotel
# 695               FairBridge Inn & Suites Miles City
# 704  Embassy Suites by Hilton Huntsville Hotel & Spa
# 705                                Sweet Sharons bnb
# 706                                  Tongchuan Hotel
#
# [374 rows x 7 columns]

# %%
# 7. Drop the rows where there is no Hotel Name.
hotel_df.count()
clean_hotel_df=hotel_df.dropna()

# %%
# 8a. Create the output File (CSV)
output_data_file = "../Vacation_Search/WeatherPy_vacation.csv"


# 8b. Export the City_Data into a csv
clean_hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.

info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
<dt>Weather Descrip</dt><dd>{Current Description}</dd>
</dl>
"""


# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map. 

locations = hotel_df[["Lat", "Lng"]]
#max_temp = hotel_df["Max Temp"]

fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)

#heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
 #            max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
#fig.add_layer(heat_layer)
fig.add_layer(marker_layer)


# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
